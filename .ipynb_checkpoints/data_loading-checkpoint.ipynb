# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

input_data = np.load("/scratch/network/For_Nathan/input_data.npy")

imin = 20
imax = 42
jmin = 10
jmax = 42

subset = input_data[jmin:jmax, imin:imax, 0]
# subset = input_data[:, :, 0]

subset[subset < 0] = 0

# print(subset)
plt.imshow(subset, norm=matplotlib.colors.LogNorm())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1707514/3623580393.py in <module>
#      13 # subset = input_data[:, :, 0]
#      14
# ---> 15 subset[subset < 0] = 0
#      16
#      17 # print(subset)
#
# NameError: name 'subset' is not defined

# %%
mask_data = np.load("/scratch/network/For_Nathan/mask.npy")

# subset_mask = mask_data[:, :]

# print(subset_mask)

print(mask_data)

# %%
label_data = np.load("/scratch/network/For_Nathan/label_data.npy")

imin = 200
imax = 420
jmin = 100
jmax = 420

subset2 = label_data[imin:imax, jmin:jmax]
print(subset2)
